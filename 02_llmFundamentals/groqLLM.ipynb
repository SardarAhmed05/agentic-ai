# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("GROQ_API_KEY")
print(api_key[:10])  # prints first 10 chars just to confirm it loaded
# Out:
# gsk_p5W6yK

# %%
import requests

def ask_llm(question):
    url = "https://api.groq.com/openai/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    body = {
        "model": "openai/gpt-oss-20b",
        "messages": [
            {"role": "user", "content": question}
        ],
        "temperature": 0.7
    }

    response = requests.post(url, headers=headers, json=body)

    if response.status_code == 200:
        data = response.json()
        return data["choices"][0]["message"]["content"]
    else:
        print(f"Error {response.status_code}: {response.text}")

answer = ask_llm("What is the capital of Pakistan?")
print(answer)
# Out:
# The capital of Pakistan is **Islamabad**.

# %%
import json

url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

response_raw = requests.post(url, headers=headers, json={
    "model": "openai/gpt-oss-20b",
    "messages": [
        {"role": "user", "content": "What is the capital of Pakistan?"}
    ],
    "temperature": 0.7
})

print(json.dumps(response_raw.json(), indent=4))
# Out:
# {
#     "id": "chatcmpl-4d6a89ae-0fb9-4502-9013-083549478f75",
#     "object": "chat.completion",
#     "created": 1782473631,
#     "model": "openai/gpt-oss-20b",
#     "choices": [
#         {
#             "index": 0,
#             "message": {
#                 "role": "assistant",
#                 "content": "The capital of Pakistan is **Islamabad**.",
#                 "reasoning": "The user asks: \"What is the capital of Pakistan?\" The answer: Islamabad. It's straightforward."
#             },
#             "logprobs": null,
#             "finish_reason": "stop"
#         }
#     ],
#     "usage": {
#         "queue_time": 0.202146144,
#         "prompt_tokens": 78,
#         "prompt_time": 0.005238736,
#         "completion_tokens": 40,
#         "completion_time": 0.045921127,
#         "total_tokens": 118,
#         "total_time": 0.051159863,
#         "completion_tokens_details": {
#             "reasoning_tokens": 21
#         }
#     },
#     "usage_breakdown": null,
#     "system_fingerprint": "fp_dd097e8790",
#     "x_groq": {
#         "id": "req_01kw1va9k0fycbxvjnrxd0wke6",
#         "seed": 1194422858
#     },
#     "service_tier": "on_demand"
# }

# %%
import requests
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

# messages = []
messages = [
    {"role": "system", "content": "You are a helpful assistant. Always respond in Urdu only, no matter what language the user writes in."}
]

def chat(user_input):
    messages.append({"role": "user", "content": user_input})
    
    response = requests.post(url, headers=headers, json={
        "model": "openai/gpt-oss-20b",
        "messages": messages,
        "temperature": 0.7
    })
    
    data = response.json()
    reply = data["choices"][0]["message"]["content"]
    
    messages.append({"role": "assistant", "content": reply})
    
    return reply

print(chat("My name is Sardar."))
print(chat("What is my name?"))
# Out:
# خوش آمدید، سردار صاحب! آپ کیسے ہیں؟
# آپ کا نام سردار ہے۔

# %%
print(chat("Who am i?"))
# Out:
# آپ سردار ہیں۔

# %%
print(chat("What is the capital of Pakistan?"))
# Out:
# پاکستان کی دارالحکومت اسلام آباد ہے۔

# %%
print(messages)
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant. Always respond in Urdu only, no matter what language the user writes in.'}, {'role': 'user', 'content': 'My name is Sardar.'}, {'role': 'assistant', 'content': 'خوش آمدید، سردار صاحب! آپ کیسے ہیں؟'}, {'role': 'user', 'content': 'What is my name?'}, {'role': 'assistant', 'content': 'آپ کا نام سردار ہے۔'}, {'role': 'user', 'content': 'Who am i?'}, {'role': 'assistant', 'content': 'آپ سردار ہیں۔'}, {'role': 'user', 'content': 'What is the capital of Pakistan?'}, {'role': 'assistant', 'content': 'پاکستان کی دارالحکومت اسلام آباد ہے۔'}]

# %%
# Weather CHATBOT
from dotenv import load_dotenv
import os
import requests
import json

load_dotenv()
api_key = os.getenv("GROQ_API_KEY")

def get_coordinates(city_name):
    url = "https://geocoding-api.open-meteo.com/v1/search"
    params = {"name": city_name, "count": 1}

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        if "results" not in data or len(data["results"]) == 0:
            print(f"No results found for {city_name}")
            return None, None
        result = data["results"][0]
        return result['latitude'], result['longitude']
    else:
        print(f"Failed to get coordinates for {city_name}")
        return None, None
    
def get_weather(city_lat, city_lon):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": city_lat,
        "longitude": city_lon,
        "current_weather": True
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        weather = data["current_weather"]
        return weather

    else:
        print(f"Failed to get weather data: {response.status_code}")

url = "https://api.groq.com/openai/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

messages = [{"role": "system", "content": "You are a weather assistant. You provide weather information based on the user's input."}]

def chat(user_input):
    messages.append({"role": "user", "content": user_input})

    response = requests.post(url, headers=headers, json={
        "model": "openai/gpt-oss-20b",
        "messages": messages,
        "temperature": 0.7
    })

    data = response.json()
    reply = data["choices"][0]["message"]["content"]
    messages.append({"role": "assistant", "content": reply})
    return reply

print("Welcome to the Weather CHATBOT!")

city_name = (input("Enter a city name to get its weather: "))
city_lat, city_lon = get_coordinates(city_name)

if city_lat is not None and city_lon is not None:
    weather = get_weather(city_lat, city_lon)
    if weather:
        print(f"Current weather in {city_name}:")
        print(f"Temperature: {weather['temperature']}°C")
        print("\n")
        first_message = f"The current weather in {city_name} is {weather['temperature']}°C, windspeed {weather['windspeed']} km/h, wind direction {weather['winddirection']}°. Describe this weather conversationally."
        print("Weather Assistant: ", chat(first_message))
    else:
        print("Could not retrieve weather data.")

while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting the Weather CHATBOT. Goodbye!")
        break
    response = chat(user_input)
    print(f"Weather Assistant: {response}")
# Out:
# Welcome to the Weather CHATBOT!
# Current weather in Karachi:
# Temperature: 30.5°C
#
#
#
# Bot: Hey there! It’s a nice, warm day in Karachi right now. The temperature’s hovering at about 30.5 °C – comfortably hot but not scorching. A gentle breeze is blowing in from the southwest at around 15.3 km/h, so you’ll feel a light, refreshing gust without it being too strong. All in all, a pleasant, breezy day to enjoy the sunshine!
# Exiting the Weather CHATBOT. Goodbye!
