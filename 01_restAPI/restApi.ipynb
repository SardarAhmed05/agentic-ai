# %%
import requests

url = "https://api.open-meteo.com/v1/forecast"

params = {
    "latitude": 24.8607,   # Karachi
    "longitude": 67.0011,
    "current_weather": True
}

response = requests.get(url, params=params)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'latitude': 24.850615, 'longitude': 66.992485, 'generationtime_ms': 0.1176595687866211, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 7.0, 'current_weather_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature': '°C', 'windspeed': 'km/h', 'winddirection': '°', 'is_day': '', 'weathercode': 'wmo code'}, 'current_weather': {'time': '2026-06-26T10:45', 'interval': 900, 'temperature': 31.7, 'windspeed': 16.6, 'winddirection': 234, 'is_day': 1, 'weathercode': 1}}

# %%
import json

print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "latitude": 24.850615,
#     "longitude": 66.992485,
#     "generationtime_ms": 0.1176595687866211,
#     "utc_offset_seconds": 0,
#     "timezone": "GMT",
#     "timezone_abbreviation": "GMT",
#     "elevation": 7.0,
#     "current_weather_units": {
#         "time": "iso8601",
#         "interval": "seconds",
#         "temperature": "\u00b0C",
#         "windspeed": "km/h",
#         "winddirection": "\u00b0",
#         "is_day": "",
#         "weathercode": "wmo code"
#     },
#     "current_weather": {
#         "time": "2026-06-26T10:45",
#         "interval": 900,
#         "temperature": 31.7,
#         "windspeed": 16.6,
#         "winddirection": 234,
#         "is_day": 1,
#         "weathercode": 1
#     }
# }

# %%
data = response.json()

weather = data["current_weather"]

print(f"Time: {weather['time']}")
print(f"Temperature: {weather['temperature']}°C")
print(f"Wind speed: {weather['windspeed']} km/h")
print(f"Weather code: {weather['weathercode']}")
# Out:
# Time: 2026-06-26T10:45
# Temperature: 31.7°C
# Wind speed: 16.6 km/h
# Weather code: 1

# %%
import requests

def get_weather(city_lat, city_lon):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": city_lat,
        "longitude": city_lon,
        "current_weather": True
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        weather = data["current_weather"]
        print(f"Temperature: {weather['temperature']}°C")
        print(f"Wind speed: {weather['windspeed']} km/h")
    else:
        print(f"Failed: {response.status_code}")

get_weather(24.857167172148515, 67.2101502022886)
# Out:
# Temperature: 32.2°C
# Wind speed: 17.8 km/h

# %%
# GET COORDINATES OF A CITY USING GEOCODING API
import requests
import json

def get_coordinates(city_name):
    url = "https://geocoding-api.open-meteo.com/v1/search"
    params = {"name": city_name, "count": 1}
    
    response = requests.get(url, params=params)
    print(json.dumps(response.json(), indent=4))

get_coordinates("Karachi")
# Out:
# {
#     "results": [
#         {
#             "id": 1174872,
#             "name": "Karachi",
#             "latitude": 24.8608,
#             "longitude": 67.0104,
#             "elevation": 8.0,
#             "feature_code": "PPLA",
#             "country_code": "PK",
#             "admin1_id": 1164807,
#             "timezone": "Asia/Karachi",
#             "population": 11624219,
#             "country_id": 1168579,
#             "country": "Pakistan",
#             "admin1": "Sindh"
#         }
#     ],
#     "generationtime_ms": 0.44465065
# }

# %%
import requests

def get_coordinates(city_name):
    url = "https://geocoding-api.open-meteo.com/v1/search"
    params = {"name": city_name, "count": 1}
    
    response = requests.get(url, params=params)
    data = response.json()
    
    result = data["results"][0]
    print(f"{result['name']}: {result['latitude']}, {result['longitude']}")

get_coordinates("Larkana")
# Out:
# Larkana: 27.55898, 68.21204

# %%
# CHECKING WEATHER FOR LARKANA

import requests

def get_weather(city_lat, city_lon):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": city_lat,
        "longitude": city_lon,
        "current_weather": True
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        weather = data["current_weather"]
        print(f"Temperature: {weather['temperature']}°C")
        print(f"Wind speed: {weather['windspeed']} km/h")
        print(f"Time: {weather['time']}")
    else:
        print(f"Failed: {response.status_code}")

get_weather(27.55898, 68.21204)
# Out:
# Temperature: 42.2°C
# Wind speed: 11.5 km/h
# Time: 2026-06-26T10:45

# %%
# Writing a program that asks a user a city name and returns the current weather for that city.

import requests
import json

def get_coordinates(city_name):
    url = "https://geocoding-api.open-meteo.com/v1/search"
    params = {"name": city_name, "count": 1}

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        if "results" not in data or len(data["results"]) == 0:
            print(f"No results found for {city_name}")
            return None, None
        result = data["results"][0]
        return result['latitude'], result['longitude']
    else:
        print(f"Failed to get coordinates for {city_name}")
        return None, None
    
def get_weather(city_lat, city_lon):
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": city_lat,
        "longitude": city_lon,
        "current_weather": True
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        weather = data["current_weather"]
        print(f"Time: {weather['time']}")
        print(f"Temperature: {weather['temperature']}°C")
        print(f"Wind speed: {weather['windspeed']} km/h")

    else:
        print(f"Failed to get weather data: {response.status_code}")

print("Welcome to the Weather App!")

city_name = (input("Enter a city name to get its weather: "))
city_lat, city_lon = get_coordinates(city_name)

print(f"Weather for {city_name}")
weather = get_weather(city_lat, city_lon)
# Out:
# Welcome to the Weather App!
# Weather for New York
# Time: 2026-06-26T10:45
# Temperature: 20.5°C
# Wind speed: 8.3 km/h
